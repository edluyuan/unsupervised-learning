# %%
import numpy as np

# Load the symbol list
with open('symbols.txt', 'r') as f:
    symbols = [line.strip() for line in f.readlines()]

# Create mappings between symbols and indices
symbol_to_index = {symbol: idx for idx, symbol in enumerate(symbols)}
index_to_symbol = {idx: symbol for idx, symbol in enumerate(symbols)}
N_symbols = len(symbols)

# Load the encrypted message
with open('message.txt', 'r') as f:
    encrypted_message = f.read().strip()

# Convert encrypted message to indices
encrypted_indices = np.array([symbol_to_index[symbol] for symbol in encrypted_message])

# Load a large English text (e.g., War and Peace)
with open('war_and_peace.txt', 'r') as f:
    corpus = f.read().lower()

# Keep only the symbols we're interested in
allowed_chars = set(symbols)
corpus = ''.join([char if char in allowed_chars else ' ' for char in corpus])

# Compute unigram counts
Unigram_counts = np.zeros(N_symbols, dtype=int)
for char in corpus:
    if char in symbol_to_index:
        idx = symbol_to_index[char]
        Unigram_counts[idx] += 1

# Compute bigram counts
Bigram_counts = np.zeros((N_symbols, N_symbols), dtype=int)
for i in range(len(corpus) - 1):
    char1 = corpus[i]
    char2 = corpus[i + 1]
    if char1 in symbol_to_index and char2 in symbol_to_index:
        idx1 = symbol_to_index[char1]
        idx2 = symbol_to_index[char2]
        Bigram_counts[idx1, idx2] += 1

# Total counts for normalization
total_unigrams = np.sum(Unigram_counts)

# Compute unigram probabilities (stationary distribution)
phi = Unigram_counts / total_unigrams

# Compute bigram probabilities (transition probabilities)
psi = np.zeros((N_symbols, N_symbols))
for i in range(N_symbols):
    if Unigram_counts[i] > 0:
        psi[i, :] = Bigram_counts[i, :] / Unigram_counts[i]
    else:
        psi[i, :] = 1.0 / N_symbols  # Assign uniform probability if count is zero

# Initialize the permutation (mapping from ciphertext index to plaintext index)
# For intelligent initialization, sort symbols by frequency
plaintext_indices_sorted = np.argsort(-Unigram_counts)
encrypted_counts = np.zeros(N_symbols, dtype=int)
for idx in encrypted_indices:
    encrypted_counts[idx] += 1
ciphertext_indices_sorted = np.argsort(-encrypted_counts)

current_permutation_indices = np.zeros(N_symbols, dtype=int)
current_permutation_indices[ciphertext_indices_sorted] = plaintext_indices_sorted

# Function to compute the log probability of the decrypted message
def compute_log_likelihood(permutation_indices, encrypted_indices):
    decrypted_indices = permutation_indices[encrypted_indices]
    log_likelihood = 0.0

    # Start with the stationary probability of the first symbol
    first_index = decrypted_indices[0]
    phi_value = phi[first_index]
    log_likelihood += np.log(phi_value + 1e-10)  # Add epsilon to avoid log(0)

    # Add the log probabilities of the transitions
    prev_index = first_index
    for idx in decrypted_indices[1:]:
        psi_value = psi[prev_index, idx]
        log_likelihood += np.log(psi_value + 1e-10)  # Add epsilon to avoid log(0)
        prev_index = idx

    return log_likelihood

# Metropolis-Hastings sampler parameters
num_iterations = 10000
print_interval = 100  # Print decrypted text every 100 iterations

# Store the best permutation found
best_permutation_indices = current_permutation_indices.copy()
best_log_likelihood = compute_log_likelihood(current_permutation_indices, encrypted_indices)

# Run the Metropolis-Hastings sampler
for iteration in range(1, num_iterations + 1):
    # Propose a new permutation by swapping two symbols
    swap_indices = np.random.choice(N_symbols, size=2, replace=False)
    proposal_permutation = current_permutation_indices.copy()
    # Swap the indices
    proposal_permutation[swap_indices[0]], proposal_permutation[swap_indices[1]] = (
        proposal_permutation[swap_indices[1]],
        proposal_permutation[swap_indices[0]],
    )

    # Compute the log likelihoods
    current_log_likelihood = compute_log_likelihood(current_permutation_indices, encrypted_indices)
    proposal_log_likelihood = compute_log_likelihood(proposal_permutation, encrypted_indices)

    # Compute acceptance probability
    acceptance_probability = min(1, np.exp(proposal_log_likelihood - current_log_likelihood))

    # Accept or reject the proposal
    if np.random.rand() < acceptance_probability:
        current_permutation_indices = proposal_permutation
        current_log_likelihood = proposal_log_likelihood

        # Update the best permutation if needed
        if current_log_likelihood > best_log_likelihood:
            best_permutation_indices = current_permutation_indices.copy()
            best_log_likelihood = current_log_likelihood

    # Print the current decryption every 100 iterations
    if iteration % print_interval == 0:
        decrypted_indices = current_permutation_indices[encrypted_indices[:60]]
        decrypted_text = ''.join([index_to_symbol[idx] for idx in decrypted_indices])
        print(f"Iteration {iteration}: {decrypted_text}")

# Final decrypted message
full_decrypted_indices = best_permutation_indices[encrypted_indices]
full_decrypted_text = ''.join([index_to_symbol[idx] for idx in full_decrypted_indices])

print("\nDecrypted Message:")
print(full_decrypted_text)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/18/wz5v3z6x7_gdgjx4t9zvjzxc0000gn/T/ipykernel_2020/497238323.py in <module>
#      15
#      16 # Convert encrypted message to indices
# ---> 17 encrypted_indices = np.array([symbol_to_index[symbol] for symbol in encrypted_message])
#      18
#      19 # Load a large English text (e.g., War and Peace)
#
# /var/folders/18/wz5v3z6x7_gdgjx4t9zvjzxc0000gn/T/ipykernel_2020/497238323.py in <listcomp>(.0)
#      15
#      16 # Convert encrypted message to indices
# ---> 17 encrypted_indices = np.array([symbol_to_index[symbol] for symbol in encrypted_message])
#      18
#      19 # Load a large English text (e.g., War and Peace)
#
# KeyError: ' '

# %%
import numpy as np

# (a) Learn the transition statistics of letters and punctuation in English

# Load the symbol list
def load_symbols(symbols_file):
    with open(symbols_file, 'r') as f:
        symbols = [line.rstrip('\n') for line in f]
    symbols = [symbol if symbol else ' ' for symbol in symbols]
    return symbols

symbols = load_symbols('symbols.txt')

# Create mappings between symbols and indices
symbol_to_index = {symbol: idx for idx, symbol in enumerate(symbols)}
index_to_symbol = {idx: symbol for idx, symbol in enumerate(symbols)}
N_symbols = len(symbols)

# Load and preprocess the corpus
def load_corpus(corpus_file):
    with open(corpus_file, 'r', encoding='utf-8') as f:
        text = f.read().lower()
    allowed_chars = set(symbols)
    text = ''.join([char if char in allowed_chars else ' ' for char in text])
    return text

corpus = load_corpus('war_and_peace.txt')

# Compute unigram counts
unigram_counts = np.zeros(N_symbols, dtype=int)
for char in corpus:
    idx = symbol_to_index[char]
    unigram_counts[idx] += 1

# Compute bigram counts
bigram_counts = np.zeros((N_symbols, N_symbols), dtype=int)
for i in range(len(corpus) - 1):
    idx1 = symbol_to_index[corpus[i]]
    idx2 = symbol_to_index[corpus[i + 1]]
    bigram_counts[idx1, idx2] += 1

# Apply Laplace smoothing
unigram_counts += 1
bigram_counts += 1

# Compute unigram probabilities (stationary distribution)
phi = unigram_counts / np.sum(unigram_counts)

# Compute bigram probabilities (transition probabilities)
bigram_totals = bigram_counts.sum(axis=1, keepdims=True)
psi = bigram_counts / bigram_totals

# (d) Implement the MH sampler and run it on the encrypted text

# Load the encrypted message
with open('message.txt', 'r') as f:
    encrypted_message = f.read().strip()

# Ensure all symbols in the encrypted message are in symbols.txt
unique_encrypted_symbols = set(encrypted_message)
missing_symbols = unique_encrypted_symbols - set(symbols)
if missing_symbols:
    raise ValueError(f"Missing symbols: {missing_symbols}")

# Convert encrypted message to indices
encrypted_indices = np.array([symbol_to_index[s] for s in encrypted_message])

# Initialize the permutation intelligently
encrypted_counts = np.zeros(N_symbols, dtype=int)
for idx in encrypted_indices:
    encrypted_counts[idx] += 1

plaintext_indices_sorted = np.argsort(-unigram_counts)
ciphertext_indices_sorted = np.argsort(-encrypted_counts)

current_permutation = np.zeros(N_symbols, dtype=int)
current_permutation[ciphertext_indices_sorted] = plaintext_indices_sorted

# Function to compute the log probability of the decrypted message
def compute_log_likelihood(permutation, encrypted_indices):
    decrypted_indices = permutation[encrypted_indices]
    first_idx = decrypted_indices[0]
    log_likelihood = np.log(phi[first_idx])
    prev_indices = decrypted_indices[:-1]
    curr_indices = decrypted_indices[1:]
    psi_values = psi[prev_indices, curr_indices]
    psi_values = np.clip(psi_values, a_min=1e-12, a_max=None)
    log_likelihood += np.sum(np.log(psi_values))
    return log_likelihood

# Metropolis-Hastings sampler parameters
num_iterations = 500000
print_interval = 1000  # Adjust as needed

best_permutation = current_permutation.copy()
best_log_likelihood = compute_log_likelihood(current_permutation, encrypted_indices)

# Run the MH sampler
for iteration in range(1, num_iterations + 1):
    # Propose a new permutation by swapping two symbols
    swap_indices = np.random.choice(N_symbols, 2, replace=False)
    proposal_permutation = current_permutation.copy()
    i, j = swap_indices
    proposal_permutation[i], proposal_permutation[j] = proposal_permutation[j], proposal_permutation[i]

    # Compute log likelihoods
    current_ll = compute_log_likelihood(current_permutation, encrypted_indices)
    proposal_ll = compute_log_likelihood(proposal_permutation, encrypted_indices)

    # Compute acceptance probability
    delta_ll = proposal_ll - current_ll
    acceptance_prob = min(1, np.exp(delta_ll))

    # Accept or reject the proposal
    if np.random.rand() < acceptance_prob:
        current_permutation = proposal_permutation
        current_ll = proposal_ll
        # Update the best permutation found
        if current_ll > best_log_likelihood:
            best_permutation = current_permutation.copy()
            best_log_likelihood = current_ll

    # Report the current decryption at intervals
    if iteration % print_interval == 0:
        decrypted_indices = current_permutation[encrypted_indices[:60]]
        decrypted_text = ''.join([index_to_symbol[idx] for idx in decrypted_indices])
        print(f"Iteration {iteration}: {decrypted_text}")

# Output the final decrypted message
full_decrypted_indices = best_permutation[encrypted_indices]
full_decrypted_text = ''.join([index_to_symbol[idx] for idx in full_decrypted_indices])

print("\nDecrypted Message:")
print(full_decrypted_text)
# Out:
# Iteration 1000: on cd dkangei tny ckie varneithre detil cd wtsuei gtve ce lk
# Iteration 2000: un hd dtonger any htre voineracie dearl hd wasker gave he lt
# Iteration 3000: on py yuinget and pute cilnetable yeatr py mashet gace pe ru
a habit that has opened up many curious natures to me and also made me the victim of not a few veteran bores. the abnormal mind is quick to detect and attach itself to this quality when it appears in a normal person, and so it came about that in college i was unjustly accused of being a politician, because i was privy to the secret griefs of wild, unknown men. most of the confidences were unsought--frequently i have feigned sleep, preoccupation, or a hostile levity when i realized by some unmistakable sign that an intimate revelation was quivering on the horizon--for the intimate revelations of young men or at least the terms in which they e?press them are usually plagiaristic and marred by obvious suppressions. reserving judgments is a matter of infinite hope. i am still a little afraid of missing something if i forget that, as my father snobbishly suggested, and i snobbishly repeat a sense of the fundamental decencies is parcelled out unequally at birth.

# %%
import numpy as np

# Function to load and preprocess symbols
def load_symbols(symbols_file):
    with open(symbols_file, 'r') as f:
        symbols = [line.rstrip('\n') for line in f]
    symbols = [symbol if symbol else ' ' for symbol in symbols]
    return symbols

# Load the symbol list
symbols = load_symbols('symbols.txt')

# Create mappings between symbols and indices
symbol_to_index = {symbol: idx for idx, symbol in enumerate(symbols)}
index_to_symbol = {idx: symbol for idx, symbol in enumerate(symbols)}
N_symbols = len(symbols)

# Verify that space is correctly mapped
if ' ' not in symbol_to_index:
    raise ValueError("Space character ' ' is not present in symbols.txt.")

# Load the encrypted message
with open('message.txt', 'r') as f:
    encrypted_message = f.read().strip()

# Ensure all symbols in the encrypted message are in symbols.txt
unique_encrypted_symbols = set(encrypted_message)
missing_symbols = unique_encrypted_symbols - set(symbols)
if missing_symbols:
    raise ValueError(f"Missing symbols in symbols.txt: {missing_symbols}")

# Convert encrypted message to indices
encrypted_indices = np.array([symbol_to_index[s] for s in encrypted_message])

# Load and preprocess the corpus
def load_corpus(corpus_file):
    with open(corpus_file, 'r', encoding='utf-8') as f:
        text = f.read().lower()
    allowed_chars = set(symbols)
    text = ''.join([char if char in allowed_chars else ' ' for char in text])
    return text

corpus = load_corpus('war_and_peace.txt')

# Compute unigram counts in corpus
unigram_counts = np.zeros(N_symbols, dtype=int)
for char in corpus:
    idx = symbol_to_index[char]
    unigram_counts[idx] += 1

# Compute bigram counts in corpus
bigram_counts = np.zeros((N_symbols, N_symbols), dtype=int)
for i in range(len(corpus) - 1):
    idx1 = symbol_to_index[corpus[i]]
    idx2 = symbol_to_index[corpus[i + 1]]
    bigram_counts[idx1, idx2] += 1

# Apply Laplace smoothing to counts
unigram_counts += 1
bigram_counts += 1

# Compute unigram probabilities (stationary distribution)
phi = unigram_counts / np.sum(unigram_counts)

# Compute bigram probabilities (transition probabilities)
bigram_totals = bigram_counts.sum(axis=1, keepdims=True)
psi = bigram_counts / bigram_totals

# Compute unigram counts in encrypted message
encrypted_unigram_counts = np.zeros(N_symbols, dtype=int)
for idx in encrypted_indices:
    encrypted_unigram_counts[idx] += 1

# Compute bigram counts in encrypted message
encrypted_bigram_counts = np.zeros((N_symbols, N_symbols), dtype=int)
for i in range(len(encrypted_indices) - 1):
    idx1 = encrypted_indices[i]
    idx2 = encrypted_indices[i + 1]
    encrypted_bigram_counts[idx1, idx2] += 1

# Intelligent Initialization
# Step 1: Initial mapping based on unigram frequencies
plaintext_indices_sorted = np.argsort(-unigram_counts)
ciphertext_indices_sorted = np.argsort(-encrypted_unigram_counts)

initial_permutation = np.zeros(N_symbols, dtype=int)
initial_permutation[ciphertext_indices_sorted] = plaintext_indices_sorted

# Step 2: Refinement using bigram frequencies
# We will perform a few iterations to adjust the initial mapping

def permutation(permutation, plaintext_bigram_counts, ciphertext_bigram_counts, iterations=5):
    for _ in range(iterations):
        # For each symbol, find the best mapping based on bigram frequencies
        for cipher_idx in range(N_symbols):
            # Get the current mapping
            plain_idx = permutation[cipher_idx]
            # Compute the score for current mapping
            current_score = np.sum(np.abs(
                ciphertext_bigram_counts[cipher_idx] - plaintext_bigram_counts[plain_idx]
            ))
            # Try swapping with other symbols to find a better mapping
            for other_cipher_idx in range(N_symbols):
                if other_cipher_idx == cipher_idx:
                    continue
                other_plain_idx = permutation[other_cipher_idx]
                # Swap and compute new score
                permutation[cipher_idx], permutation[other_cipher_idx] = other_plain_idx, plain_idx
                new_score = np.sum(np.abs(
                    ciphertext_bigram_counts[cipher_idx] - plaintext_bigram_counts[other_plain_idx]
                )) + np.sum(np.abs(
                    ciphertext_bigram_counts[other_cipher_idx] - plaintext_bigram_counts[plain_idx]
                ))
                # If new score is better, keep the swap
                if new_score < current_score:
                    current_score = new_score
                    plain_idx = other_plain_idx
                else:
                    # Swap back
                    permutation[cipher_idx], permutation[other_cipher_idx] = plain_idx, other_plain_idx
    return permutation

# Normalize bigram counts for comparison
plaintext_bigram_freq = bigram_counts / bigram_counts.sum()
ciphertext_bigram_freq = encrypted_bigram_counts / encrypted_bigram_counts.sum()

# Refine the initial permutation
current_permutation = initial_permutation.copy()
current_permutation = permutation(
    current_permutation, plaintext_bigram_freq, ciphertext_bigram_freq, iterations=3
)

# Function to compute the log probability of the decrypted message
def compute_log_likelihood(permutation, encrypted_indices):
    decrypted_indices = permutation[encrypted_indices]
    first_idx = decrypted_indices[0]
    log_likelihood = np.log(phi[first_idx])
    prev_indices = decrypted_indices[:-1]
    curr_indices = decrypted_indices[1:]
    psi_values = psi[prev_indices, curr_indices]
    psi_values = np.clip(psi_values, a_min=1e-12, a_max=None)
    log_likelihood += np.sum(np.log(psi_values))
    return log_likelihood

# Metropolis-Hastings sampler parameters
num_iterations = 100000
print_interval = 10000  # Adjust as needed

best_permutation = current_permutation.copy()
best_log_likelihood = compute_log_likelihood(current_permutation, encrypted_indices)

# Run the MH sampler
for iteration in range(1, num_iterations + 1):
    # Propose a new permutation by swapping two symbols
    swap_indices = np.random.choice(N_symbols, 2, replace=False)
    proposal_permutation = current_permutation.copy()
    i, j = swap_indices
    proposal_permutation[i], proposal_permutation[j] = proposal_permutation[j], proposal_permutation[i]

    # Compute log likelihoods
    current_ll = compute_log_likelihood(current_permutation, encrypted_indices)
    proposal_ll = compute_log_likelihood(proposal_permutation, encrypted_indices)

    # Compute acceptance probability
    delta_ll = proposal_ll - current_ll
    acceptance_prob = min(1, np.exp(delta_ll))

    # Accept or reject the proposal
    if np.random.rand() < acceptance_prob:
        current_permutation = proposal_permutation
        current_ll = proposal_ll
        # Update the best permutation found
        if current_ll > best_log_likelihood:
            best_permutation = current_permutation.copy()
            best_log_likelihood = current_ll

    # Report the current decryption at intervals
    if iteration % print_interval == 0:
        decrypted_indices = current_permutation[encrypted_indices[:60]]
        decrypted_text = ''.join([index_to_symbol[idx] for idx in decrypted_indices])
        print(f"Iteration {iteration}: {decrypted_text}")

# Output the final decrypted message
full_decrypted_indices = best_permutation[encrypted_indices]
full_decrypted_text = ''.join([index_to_symbol[idx] for idx in full_decrypted_indices])

print("\nDecrypted Message:")
print(full_decrypted_text)
# Out:
# Iteration 10000: in my younger and more vulnerable years my father gave me so
# Iteration 20000: in my younger and more vulnerable years my father gave me so
# Iteration 30000: in my younger and more vulnerable years my father gave me so
# Iteration 40000: in my younger and more vulnerable years my father gave me so
# Iteration 50000: in my younger and more vulnerable years my father gave me so
# Iteration 60000: in my younger and more vulnerable years my father gave me so
# Iteration 70000: in my younger and more vulnerable years my father gave me so
# Iteration 80000: in my younger and more vulnerable years my father gave me so
# Iteration 90000: in my younger and more vulnerable years my father gave me so
# Iteration 100000: in my younger and more vulnerable years my father gave me so
#
# Decrypted Message:
# in my younger and more vulnerable years my father gave me some advice that ixve been turning over in my mind ever since. *whenever you feel like criticizing any one,* he told me, *just remember that all the people in this world havenxt had the advantages that youxve had.* he didnxt say any more but wexve always been unusually communicative in a reserved way, and i understood that he meant a great deal more than that. in consequence ixm inclined to reserve all judgments, a habit that has opened up many curious natures to me and also made me the victim of not a few veteran bores. the abnormal mind is quick to detect and attach itself to this quality when it appears in a normal person, and so it came about that in college i was unjustly accused of being a politician, because i was privy to the secret griefs of wild, unknown men. most of the confidences were unsought--frequently i have feigned sleep, preoccupation, or a hostile levity when i realized by some unmistakable sign that an intimate revelation was quivering on the horizon--for the intimate revelations of young men or at least the terms in which they e?press them are usually plagiaristic and marred by obvious suppressions. reserving judgments is a matter of infinite hope. i am still a little afraid of missing something if i forget that, as my father snobbishly suggested, and i snobbishly repeat a sense of the fundamental decencies is parcelled out unequally at birth.

# %%
import numpy as np
import matplotlib.pyplot as plt
# Function to load and preprocess symbols from 'symbols.txt'
def load_symbols(symbols_file):
    """
    Load symbols from a file, replacing empty lines with a space character.

    Args:
        symbols_file (str): Path to the symbols file.

    Returns:
        list: A list of symbols.
    """
    with open(symbols_file, 'r') as f:
        # Read each line, removing the trailing newline character
        symbols = [line.rstrip('\n') for line in f]
    # Replace empty strings with a space character to represent '⟨space⟩'
    symbols = [symbol if symbol else ' ' for symbol in symbols]
    return symbols

# Load the list of symbols from 'symbols.txt'
symbols = load_symbols('symbols.txt')

# Create dictionaries to map symbols to indices and vice versa
symbol_to_index = {symbol: idx for idx, symbol in enumerate(symbols)}
index_to_symbol = {idx: symbol for idx, symbol in enumerate(symbols)}
N_symbols = len(symbols)  # Total number of unique symbols

# Verify that the space character is present in the symbol mappings
if ' ' not in symbol_to_index:
    raise ValueError("Space character ' ' is not present in symbols.txt.")

# Load the encrypted message from 'message.txt'
with open('message.txt', 'r') as f:
    encrypted_message = f.read().strip()

# Identify all unique symbols present in the encrypted message
unique_encrypted_symbols = set(encrypted_message)

# Check for any symbols in the encrypted message that are not in 'symbols.txt'
missing_symbols = unique_encrypted_symbols - set(symbols)
if missing_symbols:
    raise ValueError(f"Missing symbols in symbols.txt: {missing_symbols}")

# Convert the encrypted message symbols to their corresponding indices
encrypted_indices = np.array([symbol_to_index[s] for s in encrypted_message])

# Function to load and preprocess the corpus from 'war_and_peace.txt'
def load_corpus(corpus_file):
    """
    Load and preprocess the corpus text by retaining only allowed symbols.

    Args:
        corpus_file (str): Path to the corpus file.

    Returns:
        str: Preprocessed corpus text.
    """
    with open(corpus_file, 'r', encoding='utf-8') as f:
        text = f.read().lower()  # Convert text to lowercase for consistency
    allowed_chars = set(symbols)  # Define allowed characters based on symbols
    # Replace any character not in allowed_chars with a space
    text = ''.join([char if char in allowed_chars else ' ' for char in text])
    return text

# Load and preprocess the corpus
corpus = load_corpus('war_and_peace.txt')

# Initialize an array to count unigram (single symbol) occurrences in the corpus
unigram_counts = np.zeros(N_symbols, dtype=int)
for char in corpus:
    idx = symbol_to_index[char]  # Get the index of the current character
    unigram_counts[idx] += 1      # Increment the count for this symbol

# Initialize a 2D array to count bigram (pair of symbols) occurrences in the corpus
bigram_counts = np.zeros((N_symbols, N_symbols), dtype=int)
for i in range(len(corpus) - 1):
    idx1 = symbol_to_index[corpus[i]]       # Index of the first symbol in the bigram
    idx2 = symbol_to_index[corpus[i + 1]]   # Index of the second symbol in the bigram
    bigram_counts[idx1, idx2] += 1           # Increment the count for this bigram

# Apply Laplace (add-one) smoothing to unigram and bigram counts to avoid zero probabilities
unigram_counts += 1
bigram_counts += 1

# Compute unigram probabilities (stationary distribution) by normalizing unigram counts
phi = unigram_counts / np.sum(unigram_counts)

# Compute bigram probabilities (transition probabilities) by normalizing bigram counts
bigram_totals = bigram_counts.sum(axis=1, keepdims=True)  # Sum of bigrams starting with each symbol
psi = bigram_counts / bigram_totals

# Initialize an array to count unigram occurrences in the encrypted message
encrypted_unigram_counts = np.zeros(N_symbols, dtype=int)
for idx in encrypted_indices:
    encrypted_unigram_counts[idx] += 1  # Increment count for each symbol in the encrypted message

# Initialize an array to count bigram occurrences in the encrypted message
encrypted_bigram_counts = np.zeros((N_symbols, N_symbols), dtype=int)
for i in range(len(encrypted_indices) - 1):
    idx1 = encrypted_indices[i]       # Index of the first symbol in the bigram
    idx2 = encrypted_indices[i + 1]   # Index of the second symbol in the bigram
    encrypted_bigram_counts[idx1, idx2] += 1  # Increment the count for this bigram

# Intelligent Initialization Step 1: Map ciphertext symbols to plaintext symbols based on unigram frequencies
# Sort plaintext symbols by descending unigram counts (most frequent first)
plaintext_indices_sorted = np.argsort(-unigram_counts)
# Sort ciphertext symbols by descending unigram counts in the encrypted message
ciphertext_indices_sorted = np.argsort(-encrypted_unigram_counts)

# Initialize the permutation array where index corresponds to ciphertext symbol
# and value corresponds to plaintext symbol
initial_permutation = np.zeros(N_symbols, dtype=int)
initial_permutation[ciphertext_indices_sorted] = plaintext_indices_sorted

# Function to refine the permutation based on bigram frequency alignment
def permutation(permutation, plaintext_bigram_counts, ciphertext_bigram_counts, iterations=5):
    """
    Refine the initial permutation by swapping symbol mappings to better align bigram frequencies.

    Args:
        permutation (np.ndarray): Current permutation array mapping ciphertext to plaintext indices.
        plaintext_bigram_counts (np.ndarray): Normalized bigram frequencies from the corpus.
        ciphertext_bigram_counts (np.ndarray): Normalized bigram frequencies from the encrypted message.
        iterations (int): Number of refinement iterations to perform.

    Returns:
        np.ndarray: Refined permutation array.
    """
    for _ in range(iterations):
        # Iterate over each ciphertext symbol
        for cipher_idx in range(N_symbols):
            # Get the current plaintext symbol mapped to this ciphertext symbol
            plain_idx = permutation[cipher_idx]
            # Compute the current score based on the absolute difference in bigram frequencies
            current_score = np.sum(
                np.abs(ciphertext_bigram_counts[cipher_idx] - plaintext_bigram_counts[plain_idx])
            )
            # Try swapping with other ciphertext symbols to find a better mapping
            for other_cipher_idx in range(N_symbols):
                if other_cipher_idx == cipher_idx:
                    continue  # Skip swapping with itself
                other_plain_idx = permutation[other_cipher_idx]
                # Swap the plaintext mappings
                permutation[cipher_idx], permutation[other_cipher_idx] = other_plain_idx, plain_idx
                # Compute the new score after swapping
                new_score = (
                    np.sum(
                        np.abs(ciphertext_bigram_counts[cipher_idx] - plaintext_bigram_counts[other_plain_idx])
                    )
                    + np.sum(
                        np.abs(ciphertext_bigram_counts[other_cipher_idx] - plaintext_bigram_counts[plain_idx])
                    )
                )
                # If the new score is better (lower), keep the swap
                if new_score < current_score:
                    current_score = new_score
                    plain_idx = other_plain_idx
                else:
                    # Revert the swap if it does not improve the score
                    permutation[cipher_idx], permutation[other_cipher_idx] = plain_idx, other_plain_idx
    return permutation

# Normalize bigram counts to frequencies for comparison
plaintext_bigram_freq = bigram_counts / bigram_counts.sum()
ciphertext_bigram_freq = encrypted_bigram_counts / encrypted_bigram_counts.sum()

# Refine the initial permutation to better align bigram frequencies
current_permutation = initial_permutation.copy()
current_permutation = permutation(
    current_permutation, plaintext_bigram_freq, ciphertext_bigram_freq, iterations=3
)

# Function to compute the log-likelihood of the decrypted message given a permutation
def compute_log_likelihood(permutation, encrypted_indices):
    """
    Compute the log-likelihood of the decrypted message based on the current permutation.

    Args:
        permutation (np.ndarray): Current permutation array mapping ciphertext to plaintext indices.
        encrypted_indices (np.ndarray): Array of indices representing the encrypted message.

    Returns:
        float: Log-likelihood value.
    """
    decrypted_indices = permutation[encrypted_indices]  # Decrypt the message using the permutation
    first_idx = decrypted_indices[0]                    # Index of the first decrypted symbol
    log_likelihood = np.log(phi[first_idx])            # Add log probability of the first symbol
    prev_indices = decrypted_indices[:-1]               # All symbols except the last
    curr_indices = decrypted_indices[1:]                # All symbols except the first
    psi_values = psi[prev_indices, curr_indices]        # Transition probabilities for each bigram
    psi_values = np.clip(psi_values, a_min=1e-12, a_max=None)  # Avoid log(0) by clipping
    log_likelihood += np.sum(np.log(psi_values))       # Add log probabilities of transitions
    return log_likelihood

# Metropolis-Hastings sampler parameters
num_iterations = 10000    # Total number of MH iterations
print_interval = 1000     # Interval at which to print decrypted text

# Initialize the best permutation tracking variables
best_permutation = current_permutation.copy()
best_log_likelihood = compute_log_likelihood(current_permutation, encrypted_indices)

# Run the Metropolis-Hastings sampler
for iteration in range(1, num_iterations + 1):
    # Propose a new permutation by swapping two randomly selected symbols
    swap_indices = np.random.choice(N_symbols, 2, replace=False)
    proposal_permutation = current_permutation.copy()
    i, j = swap_indices
    proposal_permutation[i], proposal_permutation[j] = proposal_permutation[j], proposal_permutation[i]

    # Compute log-likelihoods for the current and proposed permutations
    current_ll = compute_log_likelihood(current_permutation, encrypted_indices)
    proposal_ll = compute_log_likelihood(proposal_permutation, encrypted_indices)

    # Calculate the difference in log-likelihoods
    delta_ll = proposal_ll - current_ll
    # Compute the acceptance probability using the Metropolis criterion
    acceptance_prob = min(1, np.exp(delta_ll))

    # Decide whether to accept the proposed permutation
    if np.random.rand() < acceptance_prob:
        current_permutation = proposal_permutation  # Accept the proposal
        current_ll = proposal_ll
        # Update the best permutation if the new one has a higher log-likelihood
        if current_ll > best_log_likelihood:
            best_permutation = current_permutation.copy()
            best_log_likelihood = current_ll

    # Print the decrypted text of the first 60 symbols at specified intervals
    if iteration % print_interval == 0:
        decrypted_indices = current_permutation[encrypted_indices[:60]]  # Decrypt first 60 symbols
        decrypted_text = ''.join([index_to_symbol[idx] for idx in decrypted_indices])
        print(f"Iteration {iteration}: {decrypted_text}")

# After all iterations, decrypt the full message using the best permutation found
full_decrypted_indices = best_permutation[encrypted_indices]
full_decrypted_text = ''.join([index_to_symbol[idx] for idx in full_decrypted_indices])

# Print the final decrypted message
print("\nDecrypted Message:")
print(full_decrypted_text)
# Out:
# Iteration 1000: ur d. .ahryen irm dane chsrenizse .eint d. fiolen yice de ta
# Iteration 2000: un m. .ahnyer ind mare chsneripse .eirt m. fioler yice me ta
# Iteration 3000: an m. .uonyel ind mule vornelipre .eils m. fithel yive me su
# Iteration 4000: in m. .ounkel and mole vurnelapre .eals m. fathel kave me so
# Iteration 5000: in m. .ounkel and mole vurnelapre .eals m. fathel kave me so
# Iteration 6000: in m. .oungel and mole vurnelabre .eals m. fathel gave me so
# Iteration 7000: in my younger and more vulnerable years my father gave me so
# Iteration 8000: in my younger and more vulnerable years my father gave me so
# Iteration 9000: in my younger and more vulnerable years my father gave me so
# Iteration 10000: in my younger and more vulnerable years my father gave me so
#
# Decrypted Message:
# in my younger and more vulnerable years my father gave me some advice that ixve been turning over in my mind ever since. *whenever you feel like criticizing any one,* he told me, *just remember that all the people in this world havenxt had the advantages that youxve had.* he didnxt say any more but wexve always been unusually communicative in a reserved way, and i understood that he meant a great deal more than that. in consequence ixm inclined to reserve all judgments, a habit that has opened up many curious natures to me and also made me the victim of not a few veteran bores. the abnormal mind is quick to detect and attach itself to this quality when it appears in a normal person, and so it came about that in college i was unjustly accused of being a politician, because i was privy to the secret griefs of wild, unknown men. most of the confidences were unsought--frequently i have feigned sleep, preoccupation, or a hostile levity when i realized by some unmistakable sign that an intimate revelation was quivering on the horizon--for the intimate revelations of young men or at least the terms in which they e!press them are usually plagiaristic and marred by obvious suppressions. reserving judgments is a matter of infinite hope. i am still a little afraid of missing something if i forget that, as my father snobbishly suggested, and i snobbishly repeat a sense of the fundamental decencies is parcelled out unequally at birth.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Function to load and preprocess symbols from 'symbols.txt'
def load_symbols(symbols_file):
    """
    Load symbols from a file, replacing empty lines with a space character.

    Args:
        symbols_file (str): Path to the symbols file.

    Returns:
        list: A list of symbols.
    """
    with open(symbols_file, 'r') as f:
        symbols = [line.rstrip('\n') for line in f]
    # Replace empty strings with space character to represent '⟨space⟩'
    symbols = [symbol if symbol else ' ' for symbol in symbols]
    return symbols

# Load the list of symbols from 'symbols.txt'
symbols = load_symbols('symbols.txt')

# Create dictionaries to map symbols to indices and vice versa
symbol_to_index = {symbol: idx for idx, symbol in enumerate(symbols)}
index_to_symbol = {idx: symbol for idx, symbol in enumerate(symbols)}
N_symbols = len(symbols)  # Total number of unique symbols

# Verify that the space character is present in the symbol mappings
if ' ' not in symbol_to_index:
    raise ValueError("Space character ' ' is not present in symbols.txt.")

# Load the encrypted message from 'message.txt'
with open('message.txt', 'r') as f:
    encrypted_message = f.read().strip()

# Identify all unique symbols present in the encrypted message
unique_encrypted_symbols = set(encrypted_message)

# Check for any symbols in the encrypted message that are not in 'symbols.txt'
missing_symbols = unique_encrypted_symbols - set(symbols)
if missing_symbols:
    raise ValueError(f"Missing symbols in symbols.txt: {missing_symbols}")

# Convert the encrypted message symbols to their corresponding indices
encrypted_indices = np.array([symbol_to_index[s] for s in encrypted_message])

# Function to load and preprocess the corpus from 'war_and_peace.txt'
def load_corpus(corpus_file):
    """
    Load and preprocess the corpus text by retaining only allowed symbols.

    Args:
        corpus_file (str): Path to the corpus file.

    Returns:
        str: Preprocessed corpus text.
    """
    with open(corpus_file, 'r', encoding='utf-8') as f:
        text = f.read().lower()  # Convert text to lowercase for consistency
    allowed_chars = set(symbols)  # Define allowed characters based on symbols
    # Replace any character not in allowed_chars with a space
    text = ''.join([char if char in allowed_chars else ' ' for char in text])
    return text

# Load and preprocess the corpus
corpus = load_corpus('war_and_peace.txt')

# Initialize an array to count unigram (single symbol) occurrences in the corpus
unigram_counts = np.zeros(N_symbols, dtype=int)
for char in corpus:
    idx = symbol_to_index[char]  # Get the index of the current character
    unigram_counts[idx] += 1      # Increment the count for this symbol

# Initialize a 2D array to count bigram (pair of symbols) occurrences in the corpus
bigram_counts = np.zeros((N_symbols, N_symbols), dtype=int)
for i in range(len(corpus) - 1):
    idx1 = symbol_to_index[corpus[i]]       # Index of the first symbol in the bigram
    idx2 = symbol_to_index[corpus[i + 1]]   # Index of the second symbol in the bigram
    bigram_counts[idx1, idx2] += 1           # Increment the count for this bigram

# Apply Laplace (add-one) smoothing to unigram and bigram counts to avoid zero probabilities
unigram_counts += 1
bigram_counts += 1

# Compute unigram probabilities (stationary distribution) by normalizing unigram counts
phi = unigram_counts / np.sum(unigram_counts)

# Compute bigram probabilities (transition probabilities) by normalizing bigram counts
bigram_totals = bigram_counts.sum(axis=1, keepdims=True)  # Sum of bigrams starting with each symbol
psi = bigram_counts / bigram_totals

# Initialize an array to count unigram occurrences in the encrypted message
encrypted_unigram_counts = np.zeros(N_symbols, dtype=int)
for idx in encrypted_indices:
    encrypted_unigram_counts[idx] += 1  # Increment count for each symbol in the encrypted message

# Initialize a 2D array to count bigram occurrences in the encrypted message
encrypted_bigram_counts = np.zeros((N_symbols, N_symbols), dtype=int)
for i in range(len(encrypted_indices) - 1):
    idx1 = encrypted_indices[i]       # Index of the first symbol in the bigram
    idx2 = encrypted_indices[i + 1]   # Index of the second symbol in the bigram
    encrypted_bigram_counts[idx1, idx2] += 1  # Increment the count for this bigram

# Intelligent Initialization
# Step 1: Initial mapping based on unigram frequencies
# Sort plaintext symbols by descending unigram counts (most frequent first)
plaintext_indices_sorted = np.argsort(-unigram_counts)
# Sort ciphertext symbols by descending unigram counts in the encrypted message
ciphertext_indices_sorted = np.argsort(-encrypted_unigram_counts)

# Initialize the permutation array where index corresponds to ciphertext symbol
# and value corresponds to plaintext symbol
initial_permutation = np.zeros(N_symbols, dtype=int)
initial_permutation[ciphertext_indices_sorted] = plaintext_indices_sorted

# Function to refine the permutation based on bigram frequency alignment
def refine_permutation(permutation, plaintext_bigram_freq, ciphertext_bigram_freq, iterations=5):
    """
    Refine the initial permutation by swapping symbol mappings to better align bigram frequencies.

    Args:
        permutation (np.ndarray): Current permutation array mapping ciphertext to plaintext indices.
        plaintext_bigram_freq (np.ndarray): Normalized bigram frequencies from the corpus.
        ciphertext_bigram_freq (np.ndarray): Normalized bigram frequencies from the encrypted message.
        iterations (int): Number of refinement iterations to perform.

    Returns:
        np.ndarray: Refined permutation array.
    """
    for _ in range(iterations):
        # Iterate over each ciphertext symbol
        for cipher_idx in range(N_symbols):
            # Get the current plaintext symbol mapped to this ciphertext symbol
            plain_idx = permutation[cipher_idx]
            # Compute the current score based on the absolute difference in bigram frequencies
            current_score = np.sum(
                np.abs(ciphertext_bigram_freq[cipher_idx] - plaintext_bigram_freq[plain_idx])
            )
            # Try swapping with other ciphertext symbols to find a better mapping
            for other_cipher_idx in range(N_symbols):
                if other_cipher_idx == cipher_idx:
                    continue  # Skip swapping with itself
                other_plain_idx = permutation[other_cipher_idx]
                # Swap the plaintext mappings
                permutation[cipher_idx], permutation[other_cipher_idx] = other_plain_idx, plain_idx
                # Compute the new score after swapping
                new_score = (
                    np.sum(
                        np.abs(ciphertext_bigram_freq[cipher_idx] - plaintext_bigram_freq[other_plain_idx])
                    )
                    + np.sum(
                        np.abs(ciphertext_bigram_freq[other_cipher_idx] - plaintext_bigram_freq[plain_idx])
                    )
                )
                # If the new score is better (lower), keep the swap
                if new_score < current_score:
                    current_score = new_score
                    plain_idx = other_plain_idx
                else:
                    # Revert the swap if it does not improve the score
                    permutation[cipher_idx], permutation[other_cipher_idx] = plain_idx, other_plain_idx
    return permutation

# Normalize bigram counts to frequencies for comparison
plaintext_bigram_freq = bigram_counts / bigram_counts.sum()
ciphertext_bigram_freq = encrypted_bigram_counts / encrypted_bigram_counts.sum()

# Refine the initial permutation to better align bigram frequencies
current_permutation = initial_permutation.copy()
current_permutation = refine_permutation(
    current_permutation, plaintext_bigram_freq, ciphertext_bigram_freq, iterations=3
)

# Function to compute the log-likelihood of the decrypted message given a permutation
def compute_log_likelihood(permutation, encrypted_indices):
    """
    Compute the log-likelihood of the decrypted message based on the current permutation.

    Args:
        permutation (np.ndarray): Current permutation array mapping ciphertext to plaintext indices.
        encrypted_indices (np.ndarray): Array of indices representing the encrypted message.

    Returns:
        float: Log-likelihood value.
    """
    decrypted_indices = permutation[encrypted_indices]  # Decrypt the message using the permutation
    first_idx = decrypted_indices[0]                    # Index of the first decrypted symbol
    log_likelihood = np.log(phi[first_idx])            # Add log probability of the first symbol
    prev_indices = decrypted_indices[:-1]               # All symbols except the last
    curr_indices = decrypted_indices[1:]                # All symbols except the first
    psi_values = psi[prev_indices, curr_indices]        # Transition probabilities for each bigram
    psi_values = np.clip(psi_values, a_min=1e-12, a_max=None)  # Avoid log(0) by clipping
    log_likelihood += np.sum(np.log(psi_values))       # Add log probabilities of transitions
    return log_likelihood

# Metropolis-Hastings sampler parameters
num_iterations = 10000    # Total number of MH iterations
print_interval = 1000   # Interval at which to print decrypted text

# Initialize variables to track the best permutation and its log-likelihood
best_permutation = current_permutation.copy()
best_log_likelihood = compute_log_likelihood(current_permutation, encrypted_indices)

# Lists to store log-likelihoods and acceptance rates for plotting
log_likelihood_history = []
acceptance_history = []

# Counter for accepted proposals to calculate acceptance rate
accepted = 0

# Run the Metropolis-Hastings sampler
for iteration in range(1, num_iterations + 1):
    # Propose a new permutation by swapping two randomly selected symbols
    swap_indices = np.random.choice(N_symbols, 2, replace=False)
    proposal_permutation = current_permutation.copy()
    i, j = swap_indices
    proposal_permutation[i], proposal_permutation[j] = proposal_permutation[j], proposal_permutation[i]

    # Compute log-likelihoods for the current and proposed permutations
    current_ll = compute_log_likelihood(current_permutation, encrypted_indices)
    proposal_ll = compute_log_likelihood(proposal_permutation, encrypted_indices)

    # Calculate the difference in log-likelihoods
    delta_ll = proposal_ll - current_ll

    # Compute the acceptance probability using the Metropolis criterion
    acceptance_prob = min(1, np.exp(delta_ll))

    # Decide whether to accept the proposed permutation
    if np.random.rand() < acceptance_prob:
        current_permutation = proposal_permutation  # Accept the proposal
        current_ll = proposal_ll
        accepted += 1  # Increment the acceptance counter

        # Update the best permutation found if the new one has a higher log-likelihood
        if current_ll > best_log_likelihood:
            best_permutation = current_permutation.copy()
            best_log_likelihood = current_ll

    # Record log-likelihood and acceptance status for plotting
    log_likelihood_history.append(best_log_likelihood)
    acceptance_history.append(accepted / iteration)  # Running acceptance rate

    # Print the decrypted text of the first 60 symbols at specified intervals
    if iteration % print_interval == 0:
        decrypted_indices = current_permutation[encrypted_indices[:60]]  # Decrypt first 60 symbols
        decrypted_text = ''.join([index_to_symbol[idx] for idx in decrypted_indices])
        print(f"Iteration {iteration}: {decrypted_text}")

# After sampling, compute the final acceptance rate
final_acceptance_rate = accepted / num_iterations
print(f"\nFinal Acceptance Rate: {final_acceptance_rate:.2f}")

# Output the final decrypted message using the best permutation found
full_decrypted_indices = best_permutation[encrypted_indices]
full_decrypted_text = ''.join([index_to_symbol[idx] for idx in full_decrypted_indices])

print("\nDecrypted Message:")
print(full_decrypted_text)

# Plotting the Log-Likelihood Over Iterations
plt.figure(figsize=(12, 6))
plt.plot(log_likelihood_history, color='blue')
plt.title('Log-Likelihood Over Iterations')
plt.xlabel('Iteration')
plt.ylabel('Log-Likelihood')
plt.grid(True)
plt.tight_layout()
plt.show()

# Plotting the Acceptance Rate Over Iterations
plt.figure(figsize=(12, 6))
plt.plot(acceptance_history, color='green')
plt.title('Acceptance Rate Over Iterations')
plt.xlabel('Iteration')
plt.ylabel('Acceptance Rate')
plt.grid(True)
plt.tight_layout()
plt.show()

# Plotting Symbol Frequency Comparison
# Compute decrypted unigram counts
decrypted_unigram_counts = np.zeros(N_symbols, dtype=int)
for idx in full_decrypted_indices:
    decrypted_unigram_counts[idx] += 1

# Normalize counts to get frequencies
decrypted_freq = decrypted_unigram_counts / decrypted_unigram_counts.sum()
corpus_freq = unigram_counts / unigram_counts.sum()

# Plotting comparison of frequencies
plt.figure(figsize=(14, 7))
indices = np.arange(N_symbols)
width = 0.35  # Width of the bars

plt.bar(indices - width/2, corpus_freq, width, label='Corpus Frequency', alpha=0.7)
plt.bar(indices + width/2, decrypted_freq, width, label='Decrypted Frequency', alpha=0.7)

plt.xlabel('Symbol Index')
plt.ylabel('Frequency')
plt.title('Comparison of Symbol Frequencies: Corpus vs. Decrypted Message')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Iteration 1000: ir h. .afruec orm hace kfdrecosde .eocl h. wotyec uoke he la
# Iteration 2000: ir m. .ourgen ard mone vusrenayse .eanl m. fathen gave me lo
# Iteration 3000: in m. .oungel and mole vusnelayse .ealr m. fathel gave me ro
# Iteration 4000: in my younger and more vulneraple years my father gave me so
# Iteration 5000: in my younger and more vulneraple years my father gave me so
# Iteration 6000: in my younger and more vulneraple years my father gave me so
# Iteration 7000: in my younger and more vulneraple years my father gave me so
# Iteration 8000: in my younger and more vulneraple years my father gave me so
# Iteration 9000: in my younger and more vulnerable years my father gave me so
# Iteration 10000: in my younger and more vulnerable years my father gave me so
#
# Final Acceptance Rate: 0.17
#
# Decrypted Message:
# in my younger and more vulnerable years my father gave me some advice that ixve been turning over in my mind ever since. *whenever you feel like criticizing any one,* he told me, *just remember that all the people in this world havenxt had the advantages that youxve had.* he didnxt say any more but wexve always been unusually communicative in a reserved way, and i understood that he meant a great deal more than that. in consequence ixm inclined to reserve all judgments, a habit that has opened up many curious natures to me and also made me the victim of not a few veteran bores. the abnormal mind is quick to detect and attach itself to this quality when it appears in a normal person, and so it came about that in college i was unjustly accused of being a politician, because i was privy to the secret griefs of wild, unknown men. most of the confidences were unsought--frequently i have feigned sleep, preoccupation, or a hostile levity when i realized by some unmistakable sign that an intimate revelation was quivering on the horizon--for the intimate revelations of young men or at least the terms in which they e!press them are usually plagiaristic and marred by obvious suppressions. reserving judgments is a matter of infinite hope. i am still a little afraid of missing something if i forget that, as my father snobbishly suggested, and i snobbishly repeat a sense of the fundamental decencies is parcelled out unequally at birth.

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/18/wz5v3z6x7_gdgjx4t9zvjzxc0000gn/T/ipykernel_2020/1373764494.py in <module>
#      13 from scipy.special import gammaln
#      14 import matplotlib.pyplot as plt
# ---> 15 import seaborn as sns
#      16 sns.set(font_scale=2)
#      17
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/__init__.py in <module>
#       7 from .categorical import *  # noqa: F401,F403
#       8 from .distributions import *  # noqa: F401,F403
# ----> 9 from .matrix import *  # noqa: F401,F403
#      10 from .miscplot import *  # noqa: F401,F403
#      11 from .axisgrid import *  # noqa: F401,F403
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/matrix.py in <module>
#      10 from scipy.cluster import hierarchy
#      11
# ---> 12 from . import cm
#      13 from .axisgrid import Grid
#      14 from .utils import (
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/cm.py in <module>
#    1580     locals()[_name + "_r"] = _cmap_r
#    1581
# -> 1582     mpl_cm.register_cmap(_name, _cmap)
#    1583     mpl_cm.register_cmap(_name + "_r", _cmap_r)
#    1584
#
# AttributeError: module 'matplotlib.cm' has no attribute 'register_cmap'
